# %%
#How do you load a CSV file into a pandas dataframe?
import pandas as pd
df=pd.read_csv(r"D:\Pandas-df\Global-Superstore.csv")

# %%
#2. How do you see the first 5 rows of a dataframe?
df.head(5)
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891   7/31/2012   7/31/2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  02-05-2013  02-07-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  10/17/2013  10/18/2013   First Class    CR-12730
# 3   13524  ES-2013-1579342   1/28/2013   1/30/2013   First Class    KM-16375
# 4   47221     SG-2013-4320  11-05-2013  11-06-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
#3: How do you select a single column and multiple columns?
df['Sales']
# Out:
# 0        2309.650
# 1        3709.395
# 2        5175.171
# 3        2892.510
# 4        2832.960
#            ...
# 51285      65.100
# 51286       0.444
# 51287      22.920
# 51288      13.440
# 51289      61.380
# Name: Sales, Length: 51290, dtype: float64

# %%
#and multiple columns?
df.loc[:,['Sales','Country']]
# Out:
#           Sales        Country
# 0      2309.650  United States
# 1      3709.395      Australia
# 2      5175.171      Australia
# 3      2892.510        Germany
# 4      2832.960        Senegal
# ...         ...            ...
# 51285    65.100          Japan
# 51286     0.444  United States
# 51287    22.920  United States
# 51288    13.440         Brazil
# 51289    61.380      Nicaragua
#
# [51290 rows x 2 columns]

# %%
#Q5: How do you find the total number of rows and columns?
df.shape
# Out:
# (51290, 24)

# %%
#Q6: How do you check for unique values in a column?
df['Category'].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
#Q6.1: How do you count for unique values in a column?
df['Category'].nunique()
# Out:
# 3

# %%
#Q7: How do you find the maximum and minimum of a numeric column?
df['Profit'].max()
# Out:
# np.float64(8399.976)

# %%
#Q7.1: How do you find the maximum and minimum of a numeric column?
df['Profit'].min()
# Out:
# np.float64(-6599.978)

# %%
#Q8: How can you filter rows based on a condition? For ex: # All orders where Sales > 1000
df['Sales']>1000
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: Sales, Length: 51290, dtype: bool

# %%
##8.1 above one is wrong, its giving boolean , but not data, coz that boolean again should be submitted to df, then it filters and gives data as output
df[df['Sales']>1000]
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 1       26341    IN-2013-77878  02-05-2013  02-07-2013    Second Class
# 2       25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3       13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 4       47221     SG-2013-4320  11-05-2013  11-06-2013        Same Day
# ...       ...              ...         ...         ...             ...
# 39410   11068  ES-2014-1486384  08-08-2014  08-11-2014     First Class
# 39564   12383  ES-2012-5671193   5/29/2012   5/29/2012        Same Day
# 41211   14918  ES-2012-3778678  08-01-2012  08-03-2012     First Class
# 41227   32018   CA-2013-142335  12/16/2013  12/20/2013  Standard Class
# 44220   23566    IN-2012-40029   1/27/2012  02-02-2012  Standard Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %%
#8.2 Count how many orders have Sales > 1000-INterview
(df['Sales']>1000).sum()
# Out:
# np.int64(2626)

# %%
#8.3 See just Order ID and Sales for those rows -interview
df.loc[df['Sales']>1000, ['Order ID','Sales']]
# Out:
#               Order ID     Sales
# 0       CA-2012-124891  2309.650
# 1        IN-2013-77878  3709.395
# 2        IN-2013-71249  5175.171
# 3      ES-2013-1579342  2892.510
# 4         SG-2013-4320  2832.960
# ...                ...       ...
# 39410  ES-2014-1486384  1809.780
# 39564  ES-2012-5671193  5724.540
# 41211  ES-2012-3778678  1639.089
# 41227   CA-2013-142335  1652.940
# 44220    IN-2012-40029  1585.710
#
# [2626 rows x 2 columns]

# %%
#Q9: How do you get the top 5 highest values in a column? for ex, i consider highest profit.
df['Profit'].nlargest(5)
# Out:
# 329      8399.9760
# 14843    6719.9808
# 290      5039.9856
# 122      4946.3700
# 45       4630.4755
# Name: Profit, dtype: float64

# %%
#Q10: How do you count the number of orders per Ship Mode?
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: count, dtype: int64

# %%
#List all the unique Ship Modes used in the dataset.
df['Ship Mode'].unique()
# Out:
# array(['Same Day', 'Second Class', 'First Class', 'Standard Class'],
#       dtype=object)

# %%
#How many unique Customer Names are in the dataset?
df['Customer Name'].nunique()
# Out:
# 795

# %%
#Find how many orders were shipped in each Ship Mode.
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: count, dtype: int64

# %%
# Find how many orders were shipped in each Ship Mode for each Country.
df.groupby(['Country', 'Ship Mode']).size().reset_index(name='Order Count')
# Out:
#          Country       Ship Mode  Order Count
# 0    Afghanistan     First Class            6
# 1    Afghanistan    Second Class            9
# 2    Afghanistan  Standard Class           40
# 3        Albania     First Class            1
# 4        Albania        Same Day            1
# ..           ...             ...          ...
# 500       Zambia  Standard Class           56
# 501     Zimbabwe     First Class           20
# 502     Zimbabwe        Same Day            6
# 503     Zimbabwe    Second Class           13
# 504     Zimbabwe  Standard Class           41
#
# [505 rows x 3 columns]
