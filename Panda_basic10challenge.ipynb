# %%
#10 Challenges for Practice
#Challenge1. Load the dataset and display the first 10 rows.
import pandas as pd

# %%
df=pd.read_csv(r"D:\Pandas-df\Global-Superstore.csv")
df
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891   7/31/2012   7/31/2012      Same Day    RH-19495
# 1   26341    IN-2013-77878  02-05-2013  02-07-2013  Second Class    JR-16210
# 2   25330    IN-2013-71249  10/17/2013  10/18/2013   First Class    CR-12730
# 3   13524  ES-2013-1579342   1/28/2013   1/30/2013   First Class    KM-16375
# 4   47221     SG-2013-4320  11-05-2013  11-06-2013      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
import pandas as pd

# %%
df.head(10)
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0   32298   CA-2012-124891   7/31/2012   7/31/2012        Same Day
# 1   26341    IN-2013-77878  02-05-2013  02-07-2013    Second Class
# 2   25330    IN-2013-71249  10/17/2013  10/18/2013     First Class
# 3   13524  ES-2013-1579342   1/28/2013   1/30/2013     First Class
# 4   47221     SG-2013-4320  11-05-2013  11-06-2013        Same Day
# 5   22732    IN-2013-42360   6/28/2013  07-01-2013    Second Class
# 6   30570    IN-2011-81826  11-07-2011  11-09-2011     First Class
# 7   31192    IN-2012-86369   4/14/2012   4/18/2012  Standard Class
# 8   40155   CA-2014-135909  10/14/2014  10/21/2014  Standard Class
# 9   40936   CA-2012-116638   1/28/2012   1/31/2012    Second Class
#
#   Customer ID     Customer Name      Segment           City            State  \
# 0    RH-19495       Rick Hansen     Consumer  New York City         New York
# ...

# %%
#Challenge 2: Print the total number of rows and columns.

# %%
df.shape
# Out:
# (51290, 24)

# %%
#Challenge 3. Show all column names in the dataset.

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
#4. Display only the Order ID, Customer Name, and Sales columns.

# %%
print(['Order ID', 'Customer Name', 'Sales']) #this is wrong as its simply a print statement working.
# Out:
# ['Order ID', 'Customer Name', 'Sales']

# %%
# df.loc[row_selection, column_selection]
# row_selection → Which rows you want (by label or condition)
# column_selection → Which columns you want (by name)
# df → your dataset
# .loc[:, [...]] → select all rows (:) and the specified columns.. .loc is label based indexer, super useful when you want to pick rows and columns by name instead of by number.
# df.loc[df['Sales'] > 100, ['Order ID', 'Sales']]- Only rows where Sales > 100 & Show Order ID and Sales columns

# %%
df.loc[:,['Order ID', 'Customer Name', 'Sales']]
# Out:
#               Order ID     Customer Name     Sales
# 0       CA-2012-124891       Rick Hansen  2309.650
# 1        IN-2013-77878     Justin Ritter  3709.395
# 2        IN-2013-71249      Craig Reiter  5175.171
# 3      ES-2013-1579342  Katherine Murray  2892.510
# 4         SG-2013-4320       Rick Hansen  2832.960
# ...                ...               ...       ...
# 51285    IN-2014-62366   Katrina Edelman    65.100
# 51286   US-2014-102288  Zuschuss Carroll     0.444
# 51287   US-2013-155768    Laurel Beltran    22.920
# 51288   MX-2012-140767        Ross Baird    13.440
# 51289   MX-2012-134460     Mick Crebagga    61.380
#
# [51290 rows x 3 columns]

# %%
#5. Find the maximum and minimum values of Profit.

# %%
max_profit=df['Profit'].max()
print("Maximum profit: ",max_profit)
# Out:
# Maximum profit:  8399.976

# %%
min_profit=df['Profit'].min()
print("Minimum profit: ", min_profit)
# Out:
# Minimum profit:  -6599.978

# %%
#6. Count how many unique Categories exist.

# %%
unique_categories = df['Category'].nunique()
print("Number of unique Categories:", unique_categories)
# Out:
# Number of unique Categories: 3

# %%
#7. Count how many unique Countries exist in the dataset.
unique_countries = df['Country'].nunique()
print("Number of unique Countries:", unique_countries)
# Out:
# Number of unique Countries: 147

# %%
#8. Show the top 5 highest Sales values.
high_sales=df['Sales'].nlargest(5)
print("top 5 Highest sales values: ",high_sales)
# Out:
# top 5 Highest sales values:  12887    22638.480
# 329      17499.950
# 14843    13999.960
# 7399     11199.968
# 290      10499.970
# Name: Sales, dtype: float64

# %%
#9. Calculate the average Discount.
avg_discount=df['Discount'].mean()
print("Avg discount: ",avg_discount)
# Out:
# Avg discount:  0.14290754533047378

# %%
#Count how many orders were shipped with Ship Mode = "First Class"
count=df[df['Ship Mode']=='First Class'].shape[0]
print("Number of orders with First Class shipping:", count)
# Out:
# Number of orders with First Class shipping: 7505

# %%
# Explanation:

# df['Ship Mode'] == 'First Class' → creates a True/False mask for rows

# df[...] → filters only those rows

# .shape[0] → counts the number of rows (i.e., number of orders)

# %%
# Count orders for all Ship Modes
ship_counts = df['Ship Mode'].value_counts()
print(ship_counts)
# Out:
# Ship Mode
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: count, dtype: int64

# %%
#value_counts() is very handy when you want counts of all categories in a column, including Ship Mode.
